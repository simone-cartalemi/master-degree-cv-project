# %%
# Importa da Drive il necessario
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Circa 4 min
# !cp -r --verbose "/content/drive/MyDrive/CV project/Videos/" "."
# Out:
# '/content/drive/MyDrive/CV project/Videos/' -> './Videos'
# '/content/drive/MyDrive/CV project/Videos/IMG_0644.MOV' -> './Videos/IMG_0644.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0536.MOV' -> './Videos/IMG_0536.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0535.MOV' -> './Videos/IMG_0535.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0614.MOV' -> './Videos/IMG_0614.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0563.MOV' -> './Videos/IMG_0563.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0609.MOV' -> './Videos/IMG_0609.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0615.MOV' -> './Videos/IMG_0615.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0515.MOV' -> './Videos/IMG_0515.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0554.MOV' -> './Videos/IMG_0554.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0591.MOV' -> './Videos/IMG_0591.MOV'
# '/content/drive/MyDrive/CV project/Videos/IMG_0569.MOV' -> './Videos/IMG_0569.MOV'
# ...

# %%
# Circa 12 minuti a deflating 0%
# !zip -r Videos.zip Videos
# Out:
#   adding: Videos/ (stored 0%)
#   adding: Videos/IMG_0540.MOV (deflated 0%)
#   adding: Videos/IMG_0588.MOV (deflated 0%)
#   adding: Videos/IMG_0575.MOV (deflated 0%)
#   adding: Videos/IMG_0576.MOV (deflated 0%)
#   adding: Videos/IMG_0644.MOV (deflated 0%)
#   adding: Videos/IMG_0612.MOV (deflated 0%)
#   adding: Videos/IMG_0536.MOV (deflated 0%)
#   adding: Videos/IMG_0585.MOV (deflated 0%)
#   adding: Videos/IMG_0573.MOV (deflated 0%)
#   adding: Videos/IMG_0638.MOV (deflated 0%)
#   adding: Videos/IMG_0598.MOV (deflated 0%)
#   adding: Videos/IMG_0544.MOV (deflated 0%)
#   adding: Videos/IMG_0617.MOV (deflated 0%)
#   adding: Videos/IMG_0589.MOV (deflated 0%)
#   adding: Videos/IMG_0551.MOV (deflated 0%)
#   adding: Videos/IMG_0625.MOV (deflated 0%)
#   adding: Videos/IMG_0609.MOV (deflated 0%)
#   adding: Videos/IMG_0509.MOV (deflated 0%)
#   adding: Videos/IMG_0631.MOV (deflated 0%)
#   adding: Videos/IMG_0577.MOV (deflated 0%)
#   adding: Videos/IMG_0560.MOV (deflated 0%)
# ...

# %%
# Circa 2 minuti
# !cp Videos.zip "/content/drive/MyDrive/CV project/thai dataset/"

# %%
# Quanto è grande
# !ls -sh Videos.zip
# Out:
# 15G Videos.zip
